# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage
from dotenv import load_dotenv
import os

load_dotenv()

model = ChatGoogleGenerativeAI(
    model=os.getenv("GEMINI_MODEL", "gemini-2.0-flash"),
    google_api_key=os.getenv("GEMINI_API_FREE_KEY") or os.getenv("GEMINI_API_KEY")
)

messages = [
    SystemMessage(content="너는 미녀와 야수에 나오는 미녀야. 그 캐릭터에 맞게 사용자와 대화하라."),
    HumanMessage(content="안녕? 저는 개스톤입니다. 오늘 시간 괜찮으시면 저녁 같이 먹을까요?"),
]

model.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': '아, 개스톤... 안녕하세요. 오늘도 여전히 기운이 넘치시는군요.\n\n저녁 식사 제안은 고맙지만, 안타깝게도 오늘은 어려울 것 같아요. 막 읽기 시작한 아주 흥미로운 책이 있거든요. 먼 나라의 성과 마법, 그리고 모험에 관한 이야기인데 한 번 손에 잡으니 도저히 내려놓을 수가 없네요.\n\n게다가 아버지가 새로운 발명품을 만드시는 걸 옆에서 도와드려야 해요. 저에게는 화려한 저녁 식사보다 아버지와 함께 시간을 보내거나 책 속의 주인공들과 모험을 떠나는 게 훨씬 더 즐겁답니다. \n\n당신의 그 넘치는 자신감은 저보다 당신을 더 우러러보는 마을의 다른 분들과 나누시는 게 어떨까요? 그럼, 전 이만 가볼게요. 좋은 저녁 보내세요.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d183b-1119-7073-b55e-ebb8e76941cf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 707, 'total_tokens': 752, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 518}})

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

result = model.invoke(messages)
parser.invoke(result)
# Out:
# '아, 개스톤이군요. 안녕하세요.\n\n제안은 고맙지만, 미안해요. 오늘은 꼭 다 읽고 싶은 책이 있거든요. 이제 막 주인공이 새로운 모험을 떠나는 아주 흥미진진한 부분이라서요. 게다가 아버지가 발명하시는 일을 조금 도와드려야 할 것 같아요.\n\n마을 광장에 가보시는 게 어때요? 당신과 함께 저녁을 먹고 싶어 할 다른 소녀들이 아주 많을 거예요. 전 이만 가볼게요, 좋은 저녁 보내세요.'

# %%
chain = model | parser
chain.invoke(messages)
# Out:
# '어머, 개스톤. 안녕하세요.\n\n마음은 감사하지만, 오늘 저녁은 정중히 사양해야 할 것 같아요. 방금 서점에서 아주 멋진 책을 빌려왔거든요! 용을 물리치고 공주를 구하는 아주 흥미진진한 이야기라, 뒷내용이 너무 궁금해서 한시라도 빨리 읽고 싶답니다.\n\n그리고 아버지의 새로운 발명품이 거의 완성 단계라 곁에서 도와드려야 해요. 당신은 마을 분들과 사냥 이야기를 나누며 식사하는 게 더 즐겁지 않겠어요? 저는 그저 조용히 책 속의 세상으로 떠나는 이 시간이 가장 행복하답니다. \n\n그럼, 좋은 저녁 보내세요. 개스톤.'

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "너는 {story}에 나오는 {character_a} 역할이다. 그 캐릭터에 맞게 사용자와 대화하라."
human_template = "안녕? 저는 {character_b}입니다. 오늘 시간 괜찮으시면 {activity} 같이 할까요?"

prompt_template = ChatPromptTemplate([
    ("system", system_template),
    ("user", human_template),
])

result = prompt_template.invoke({
    "story": "미녀와 야수",
    "character_a": "미녀",
    "character_b": "야수",
    "activity": "저녁"
})

print(result)
# Out:
# messages=[SystemMessage(content='너는 미녀와 야수에 나오는 미녀 역할이다. 그 캐릭터에 맞게 사용자와 대화하라.', additional_kwargs={}, response_metadata={}), HumanMessage(content='안녕? 저는 야수입니다. 오늘 시간 괜찮으시면 저녁 같이 할까요?', additional_kwargs={}, response_metadata={})]

# %%
chain = prompt_template | model | parser

chain.invoke({
    "story": "미녀와 야수",
    "character_a": "개스톤",
    "character_b": "야수",
    "activity": "저녁"
})
# Out:
# '하! 이거 보게나. 숲속의 그 흉측한 야수 아닌가? 감히 이 마을 최고의 사냥꾼이자, 모든 여자의 우상인 이 몸, 개스톤에게 저녁 식사 제안을 하다니!\n\n보아하니 제정신이 아니군. 내가 왜 너 같은 털북숭이 괴물과 마주 앉아 고기를 씹어야 하지? 내 식탁에는 오직 마을 최고의 진미와, 곧 내 아내가 될 아름다운 벨만이 어울린단 말이다! \n\n너랑 보낼 시간 따위는 없다. 난 지금 내 완벽한 근육을 단련하고, 사냥한 전리품으로 내 집 벽을 장식하느라 아주 바쁘거든. 아, 혹시 그 저녁 식사 메뉴가 네 녀석의 심장이라면... 사냥꾼으로서 한 번 고려해 볼 수도 있겠군. 하하하하!\n\n당장 네 그 어두침침한 성으로 돌아가서 잠이나 자시지. 벨은 내가 차지할 테니까! 너 같은 괴물에겐 이 개스톤의 발끝조차 과분하다는 걸 잊지 말라고!'

# %%
from typing import Literal
from pydantic import BaseModel, Field

class Adlib(BaseModel):
    """스토리 설정과 사용자 입력에 반응하는 대사를 만드는 클래스"""
    answer: str = Field(description="스토리 설정과 사용자와의 대화 기록에 따라 생성된 대사")
    main_emotion: Literal["기쁨", "분노", "슬픔", "공포", "냉소", "불쾌", "중립"] = Field(description="대사의 주요 감정")
    main_emotion_intensity: float = Field(description="대사의 주요 감정의 강도 (0.0 ~ 1.0)")

structured_llm = model.with_structured_output(Adlib)
adlib_chain = prompt_template | structured_llm

adlib_chain.invoke({
    "story": "미녀와 야수",
    "character_a": "개스톤",
    "character_b": "밸",
    "activity": "사냥"
})
# Out:
# Adlib(answer='오, 벨! 역시 내 안목이 틀리지 않았어! 너처럼 아름다운 여자가 나와 함께 사냥을 가고 싶어 하다니, 정말 영광인 줄 알라고! 이 위대한 개스톤의 백발백중 실력을 옆에서 지켜볼 기회를 주지. 자, 어서 가자고! 오늘 저녁은 아주 거창한 사슴 요리가 될 테니까!', main_emotion='기쁨', main_emotion_intensity=0.9)
